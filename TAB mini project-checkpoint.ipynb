# %%
import cv2 as cv
import math

# %%
import matplotlib.pyplot as plt

# %%
net = cv.dnn.readNetFromTensorflow("graph_opt.pb")

# %%
inWidth = 368
inHeight = 368
thr = 0.2

# %%
    BODY_PARTS = { "Nose": 0, "Neck": 1, "RShoulder": 2, "RElbow": 3, "RWrist": 4,
                   "LShoulder": 5, "LElbow": 6, "LWrist": 7, "RHip": 8, "RKnee": 9,
                   "RAnkle": 10, "LHip": 11, "LKnee": 12, "LAnkle": 13, "REye": 14,
                   "LEye": 15, "REar": 16, "LEar": 17, "Background": 18 }
    BODY_PART1 = { "Nose": 0 }

    POSE_PAIRS = [ ["Neck", "RShoulder"], ["Neck", "LShoulder"], ["RShoulder", "RElbow"],
                   ["RElbow", "RWrist"], ["LShoulder", "LElbow"], ["LElbow", "LWrist"],
                   ["Neck", "RHip"], ["RHip", "RKnee"], ["RKnee", "RAnkle"], ["Neck", "LHip"],
                   ["LHip", "LKnee"], ["LKnee", "LAnkle"], ["Neck", "Nose"], ["Nose", "REye"],
                   ["REye", "REar"], ["Nose", "LEye"], ["LEye", "LEar"] ]
    print(len(BODY_PARTS))
    print(len(BODY_PART1))
# Out:
# 19
# 1

# %%
BODY_PART2 = { "NE": 1 }
element = next(iter(BODY_PART2))
print(element)
print(len(element))
# Out:
# NE
# 2

# %%
img = cv.imread("lean_pose1.jpg")

# %%
plt.imshow(img)

# %%
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %%
def pose_estimation(frame):
    frameWidth = frame.shape[1]
    frameHeight = frame.shape[0]
    inp = cv.dnn.blobFromImage(frame, 1.0, (inWidth, inHeight),(127.5, 127.5, 127.5), swapRB=True, crop=False)
    net.setInput(inp)
    out = net.forward()
    out = out[:, :19, :, :]
    
    assert(len(BODY_PARTS) == out.shape[1])

    points = []
    for i in range(len(BODY_PARTS)):
        # Slice heatmap of corresponding body's part.
        heatMap = out[0, i, :, :]

        # Originally, we try to find all the local maximums. To simplify a sample
        # we just find a global one. However only a single pose at the same time
        # could be detected this way.
        _, conf, _, point = cv.minMaxLoc(heatMap)
        x = (frameWidth * point[0]) / out.shape[3]
        y = (frameHeight * point[1]) / out.shape[2]
        print("x=",x)
        print("y=",y)
        # Add a point if it's confidence is higher than threshold.
        points.append((int(x), int(y)) if conf > thr else None)
        
    for i in range(len(BODY_PART1)):
        heatMap = out[0, i, :, :]
        _, conf, _, point = cv.minMaxLoc(heatMap)
        x1 = (frameWidth * point[0]) / out.shape[3]
        y1 = (frameHeight * point[1]) / out.shape[2]
        print("       ")
        print("x1=",x1)
        print("y1=",y1)
    for i in range(len(element)):
        heatMap = out[0, i, :, :]
        _, conf, _, point = cv.minMaxLoc(heatMap)
        x2 = (frameWidth * point[0]) / out.shape[3]
        y2 = (frameHeight * point[1]) / out.shape[2]
        print("       ")
        print("x2=",x2)
        print("y2=",y2)
        print(" ")
    distance = ((((x2-x1)**2)+((y2-y1)**2))**0.5)
    print("the distance between them is ", distance)
    for pair in POSE_PAIRS:
        partFrom = pair[0]
        partTo = pair[1]
        assert(partFrom in BODY_PARTS)
        assert(partTo in BODY_PARTS)

        idFrom = BODY_PARTS[partFrom]
        idTo = BODY_PARTS[partTo]
        
        if points[idFrom] and points[idTo]:
            cv.line(frame, points[idFrom], points[idTo], (0, 0, 0), 3)
            cv.ellipse(frame, points[idFrom], (3, 3), 0, 0, 360, (255, 255, 255), cv.FILLED)
            cv.ellipse(frame, points[idTo], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)

    t, _ = net.getPerfProfile()
    freq = cv.getTickFrequency() / 1000
    cv.putText(frame, '%.2fms' % (t / freq), (10, 20), cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0))
    return frame
    return distance

# %%
expected_image = pose_estimation(img)
# Out:
# x= 341.5
# y= 222.6086956521739
# x= 341.5
# y= 289.39130434782606
# x= 237.56521739130434
# y= 289.39130434782606
# x= 178.17391304347825
# y= 467.4782608695652
# x= 296.95652173913044
# y= 534.2608695652174
# x= 445.4347826086956
# y= 289.39130434782606
# x= 475.1304347826087
# y= 445.2173913043478
# x= 371.19565217391306
# y= 556.5217391304348
# x= 282.10869565217394
# y= 534.2608695652174
# x= 178.17391304347825
# y= 556.5217391304348
# x= 163.32608695652175
# y= 845.9130434782609
# x= 371.19565217391306
# y= 534.2608695652174
# x= 519.6739130434783
# y= 556.5217391304348
# x= 504.82608695652175
# y= 823.6521739130435
# x= 311.80434782608694
# y= 200.34782608695653
# x= 371.19565217391306
# y= 200.34782608695653
# x= 282.10869565217394
# y= 200.34782608695653
# x= 400.89130434782606
# y= 200.34782608695653
# x= 0.0
# y= 957.2173913043479
#
# x1= 341.5
# y1= 222.6086956521739
#
# x2= 341.5
# y2= 222.6086956521739
#
#
# x2= 341.5
# y2= 289.39130434782606
#
# the distance between them is  66.78260869565216

# %%
plt.imshow(cv.cvtColor(expected_image, cv.COLOR_BGR2RGB))

# %%
lean = cv.VideoCapture('lean.gif')
lean.set(3,800)
lean.set(4,800)

if not lean.isOpened():
    lean = cv.VideoCapture(0)
if not lean.isOpened():
    raise IOError("can't open the video file")
    
while cv.waitKey(1) < 0:
    hasFrame,frame = lean.read()
    if not hasFrame:
        cv.WaitKey()
        break
    frameWidth = frame.shape[1]
    frameHeight = frame.shape[0]
    inp = cv.dnn.blobFromImage(frame, 1.0, (inWidth, inHeight),(127.5, 127.5, 127.5), swapRB=True, crop=False)
    net.setInput(inp)
    out = net.forward()
    out = out[:, :19, :, :]
    
    assert(len(BODY_PARTS) == out.shape[1])

    points = []
    for i in range(len(BODY_PARTS)):
        # Slice heatmap of corresponding body's part.
        heatMap = out[0, i, :, :]

        # Originally, we try to find all the local maximums. To simplify a sample
        # we just find a global one. However only a single pose at the same time
        # could be detected this way.
        _, conf, _, point = cv.minMaxLoc(heatMap)
        x = (frameWidth * point[0]) / out.shape[3]
        y = (frameHeight * point[1]) / out.shape[2]
        # Add a point if it's confidence is higher than threshold.
        points.append((int(x), int(y)) if conf > thr else None)
        
    for i in range(len(BODY_PART1)):
        heatMap = out[0, i, :, :]
        _, conf, _, point = cv.minMaxLoc(heatMap)
        x1 = (frameWidth * point[0]) / out.shape[3]
        y1 = (frameHeight * point[1]) / out.shape[2]
        print("       ")
        print("x1=",x1)
        print("y1=",y1)
        
    for i in range(len(element)):
        heatMap = out[0, i, :, :]
        _, conf, _, point = cv.minMaxLoc(heatMap)
        x2 = (frameWidth * point[0]) / out.shape[3]
        y2 = (frameHeight * point[1]) / out.shape[2]
        print("       ")
        print("x2=",x2)
        print("y2=",y2)
    distance = ((((x2-x1)**2)+((y2-y1)**2))**0.5)
    print("the distance between them is ", distance)
    
    for i in range(len('lean.gif')):
        if distance <71:
            text = "bend pose detected: {}".format(distance)
            cv.putText(frame, text, (10, frame.shape[0] - 25),cv.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0),2)
            print("detected")
        else:
            text1 = "bend pose not detected: {}".format(distance)
            cv.putText(frame, text1, (10, frame.shape[0] - 25),cv.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0),2)
            print("not detected")

    for pair in POSE_PAIRS:
        partFrom = pair[0]
        partTo = pair[1]
        assert(partFrom in BODY_PARTS)
        assert(partTo in BODY_PARTS)

        idFrom = BODY_PARTS[partFrom]
        idTo = BODY_PARTS[partTo]
        if points[idFrom] and points[idTo]:
            cv.line(frame, points[idFrom], points[idTo], (0, 255, 0), 3)
            cv.ellipse(frame, points[idFrom], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)
            cv.ellipse(frame, points[idTo], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)

    t, _ = net.getPerfProfile()
    freq = cv.getTickFrequency() / 1000
    cv.putText(frame, '%.2fms' % (t / freq), (10, 20), cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0))
    
    cv.imshow('video executed successfully ', frame)
# Out:
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 328.69565217391306
# y2= 129.1304347826087
# the distance between them is  72.15295662229215
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 328.69565217391306
# y2= 129.1304347826087
# the distance between them is  72.15295662229215
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 129.1304347826087
# the distance between them is  77.07801757927385
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 129.1304347826087
# the distance between them is  77.07801757927385
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 344.3478260869565
# y2= 117.3913043478261
# the distance between them is  66.52173913043478
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 328.69565217391306
# y2= 117.3913043478261
# the distance between them is  60.74677055058271
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 313.04347826086956
# y1= 58.69565217391305
#
# x2= 313.04347826086956
# y2= 58.69565217391305
#
# x2= 328.69565217391306
# y2= 117.3913043478261
# the distance between them is  60.74677055058271
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 297.39130434782606
# y1= 58.69565217391305
#
# x2= 297.39130434782606
# y2= 58.69565217391305
#
# x2= 328.69565217391306
# y2= 117.3913043478261
# the distance between them is  66.52173913043481
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 297.39130434782606
# y1= 58.69565217391305
#
# x2= 297.39130434782606
# y2= 58.69565217391305
#
# x2= 328.69565217391306
# y2= 117.3913043478261
# the distance between them is  66.52173913043481
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 297.39130434782606
# y1= 58.69565217391305
#
# x2= 297.39130434782606
# y2= 58.69565217391305
#
# x2= 328.69565217391306
# y2= 117.3913043478261
# the distance between them is  66.52173913043481
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 297.39130434782606
# y1= 58.69565217391305
#
# x2= 297.39130434782606
# y2= 58.69565217391305
#
# x2= 328.69565217391306
# y2= 117.3913043478261
# the distance between them is  66.52173913043481
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 281.7391304347826
# y1= 58.69565217391305
#
# x2= 281.7391304347826
# y2= 58.69565217391305
#
# x2= 328.69565217391306
# y2= 117.3913043478261
# the distance between them is  75.16711061334213
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 281.7391304347826
# y1= 70.43478260869566
#
# x2= 281.7391304347826
# y2= 70.43478260869566
#
# x2= 313.04347826086956
# y2= 117.3913043478261
# the distance between them is  56.43471561595808
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 281.7391304347826
# y1= 70.43478260869566
#
# x2= 281.7391304347826
# y2= 70.43478260869566
#
# x2= 313.04347826086956
# y2= 117.3913043478261
# the distance between them is  56.43471561595808
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 266.0869565217391
# y1= 70.43478260869566
#
# x2= 266.0869565217391
# y2= 70.43478260869566
#
# x2= 313.04347826086956
# y2= 117.3913043478261
# the distance between them is  66.40654988534534
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 266.0869565217391
# y1= 70.43478260869566
#
# x2= 266.0869565217391
# y2= 70.43478260869566
#
# x2= 313.04347826086956
# y2= 117.3913043478261
# the distance between them is  66.40654988534534
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 266.0869565217391
# y1= 82.17391304347827
#
# x2= 266.0869565217391
# y2= 82.17391304347827
#
# x2= 297.39130434782606
# y2= 129.1304347826087
# the distance between them is  56.434715615958076
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 266.0869565217391
# y1= 82.17391304347827
#
# x2= 266.0869565217391
# y2= 82.17391304347827
#
# x2= 297.39130434782606
# y2= 129.1304347826087
# the distance between them is  56.434715615958076
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 250.43478260869566
# y1= 82.17391304347827
#
# x2= 250.43478260869566
# y2= 82.17391304347827
#
# x2= 297.39130434782606
# y2= 129.1304347826087
# the distance between them is  66.4065498853453
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 250.43478260869566
# y1= 82.17391304347827
#
# x2= 250.43478260869566
# y2= 82.17391304347827
#
# x2= 297.39130434782606
# y2= 129.1304347826087
# the distance between them is  66.4065498853453
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 250.43478260869566
# y1= 82.17391304347827
#
# x2= 250.43478260869566
# y2= 82.17391304347827
#
# x2= 297.39130434782606
# y2= 129.1304347826087
# the distance between them is  66.4065498853453
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 250.43478260869566
# y1= 82.17391304347827
#
# x2= 250.43478260869566
# y2= 82.17391304347827
#
# x2= 297.39130434782606
# y2= 129.1304347826087
# the distance between them is  66.4065498853453
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 250.43478260869566
# y1= 93.91304347826087
#
# x2= 250.43478260869566
# y2= 93.91304347826087
#
# x2= 281.7391304347826
# y2= 129.1304347826087
# the distance between them is  47.11928313440463
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 234.7826086956522
# y1= 93.91304347826087
#
# x2= 234.7826086956522
# y2= 93.91304347826087
#
# x2= 281.7391304347826
# y2= 140.8695652173913
# the distance between them is  66.40654988534534
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 234.7826086956522
# y1= 93.91304347826087
#
# x2= 234.7826086956522
# y2= 93.91304347826087
#
# x2= 281.7391304347826
# y2= 140.8695652173913
# the distance between them is  66.40654988534534
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 234.7826086956522
# y1= 105.65217391304348
#
# x2= 234.7826086956522
# y2= 105.65217391304348
#
# x2= 281.7391304347826
# y2= 140.8695652173913
# the distance between them is  58.69565217391305
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 234.7826086956522
# y1= 105.65217391304348
#
# x2= 234.7826086956522
# y2= 105.65217391304348
#
# x2= 281.7391304347826
# y2= 140.8695652173913
# the distance between them is  58.69565217391305
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 234.7826086956522
# y1= 117.3913043478261
#
# x2= 234.7826086956522
# y2= 117.3913043478261
#
# x2= 281.7391304347826
# y2= 152.6086956521739
# the distance between them is  58.69565217391304
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 234.7826086956522
# y1= 117.3913043478261
#
# x2= 234.7826086956522
# y2= 117.3913043478261
#
# x2= 281.7391304347826
# y2= 152.6086956521739
# the distance between them is  58.69565217391304
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 117.3913043478261
#
# x2= 219.1304347826087
# y2= 117.3913043478261
#
# x2= 281.7391304347826
# y2= 152.6086956521739
# the distance between them is  71.8339294592054
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 219.1304347826087
# y1= 129.1304347826087
#
# x2= 219.1304347826087
# y2= 129.1304347826087
#
# x2= 281.7391304347826
# y2= 164.34782608695653
# the distance between them is  71.83392945920541
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 219.1304347826087
# y1= 129.1304347826087
#
# x2= 219.1304347826087
# y2= 129.1304347826087
#
# x2= 266.0869565217391
# y2= 164.34782608695653
# the distance between them is  58.695652173913054
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 140.8695652173913
#
# x2= 219.1304347826087
# y2= 140.8695652173913
#
# x2= 266.0869565217391
# y2= 164.34782608695653
# the distance between them is  52.49898729782115
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 152.6086956521739
#
# x2= 219.1304347826087
# y2= 152.6086956521739
#
# x2= 266.0869565217391
# y2= 176.08695652173913
# the distance between them is  52.49898729782115
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 152.6086956521739
#
# x2= 219.1304347826087
# y2= 152.6086956521739
#
# x2= 266.0869565217391
# y2= 176.08695652173913
# the distance between them is  52.49898729782115
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 164.34782608695653
#
# x2= 219.1304347826087
# y2= 164.34782608695653
#
# x2= 266.0869565217391
# y2= 176.08695652173913
# the distance between them is  48.40167473551167
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 164.34782608695653
#
# x2= 219.1304347826087
# y2= 164.34782608695653
#
# x2= 266.0869565217391
# y2= 187.82608695652175
# the distance between them is  52.49898729782115
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 176.08695652173913
#
# x2= 219.1304347826087
# y2= 176.08695652173913
#
# x2= 266.0869565217391
# y2= 187.82608695652175
# the distance between them is  48.401674735511676
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 176.08695652173913
#
# x2= 219.1304347826087
# y2= 176.08695652173913
#
# x2= 266.0869565217391
# y2= 187.82608695652175
# the distance between them is  48.401674735511676
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 187.82608695652175
#
# x2= 219.1304347826087
# y2= 187.82608695652175
#
# x2= 266.0869565217391
# y2= 199.56521739130434
# the distance between them is  48.40167473551167
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 187.82608695652175
#
# x2= 219.1304347826087
# y2= 187.82608695652175
#
# x2= 266.0869565217391
# y2= 199.56521739130434
# the distance between them is  48.40167473551167
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 203.47826086956522
# y1= 187.82608695652175
#
# x2= 203.47826086956522
# y2= 187.82608695652175
#
# x2= 266.0869565217391
# y2= 199.56521739130434
# the distance between them is  63.69973276734667
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 203.47826086956522
# y1= 199.56521739130434
#
# x2= 203.47826086956522
# y2= 199.56521739130434
#
# x2= 266.0869565217391
# y2= 199.56521739130434
# the distance between them is  62.60869565217391
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 203.47826086956522
# y1= 199.56521739130434
#
# x2= 203.47826086956522
# y2= 199.56521739130434
#
# x2= 266.0869565217391
# y2= 199.56521739130434
# the distance between them is  62.60869565217391
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 211.30434782608697
#
# x2= 219.1304347826087
# y2= 211.30434782608697
#
# x2= 266.0869565217391
# y2= 211.30434782608697
# the distance between them is  46.95652173913044
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 203.47826086956522
# y1= 211.30434782608697
#
# x2= 203.47826086956522
# y2= 211.30434782608697
#
# x2= 266.0869565217391
# y2= 211.30434782608697
# the distance between them is  62.60869565217391
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 223.04347826086956
#
# x2= 219.1304347826087
# y2= 223.04347826086956
#
# x2= 266.0869565217391
# y2= 211.30434782608697
# the distance between them is  48.40167473551167
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 203.47826086956522
# y1= 223.04347826086956
#
# x2= 203.47826086956522
# y2= 223.04347826086956
#
# x2= 266.0869565217391
# y2= 223.04347826086956
# the distance between them is  62.60869565217391
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 203.47826086956522
# y1= 223.04347826086956
#
# x2= 203.47826086956522
# y2= 223.04347826086956
#
# x2= 266.0869565217391
# y2= 223.04347826086956
# the distance between them is  62.60869565217391
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 234.7826086956522
#
# x2= 219.1304347826087
# y2= 234.7826086956522
#
# x2= 266.0869565217391
# y2= 223.04347826086956
# the distance between them is  48.401674735511676
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 203.47826086956522
# y1= 234.7826086956522
#
# x2= 203.47826086956522
# y2= 234.7826086956522
#
# x2= 266.0869565217391
# y2= 223.04347826086956
# the distance between them is  63.699732767346674
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 246.52173913043478
#
# x2= 219.1304347826087
# y2= 246.52173913043478
#
# x2= 266.0869565217391
# y2= 234.7826086956522
# the distance between them is  48.40167473551167
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 246.52173913043478
#
# x2= 219.1304347826087
# y2= 246.52173913043478
#
# x2= 266.0869565217391
# y2= 234.7826086956522
# the distance between them is  48.40167473551167
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 246.52173913043478
#
# x2= 219.1304347826087
# y2= 246.52173913043478
#
# x2= 266.0869565217391
# y2= 234.7826086956522
# the distance between them is  48.40167473551167
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 258.2608695652174
#
# x2= 219.1304347826087
# y2= 258.2608695652174
#
# x2= 266.0869565217391
# y2= 234.7826086956522
# the distance between them is  52.498987297821145
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 258.2608695652174
#
# x2= 219.1304347826087
# y2= 258.2608695652174
#
# x2= 281.7391304347826
# y2= 246.52173913043478
# the distance between them is  63.699732767346696
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 258.2608695652174
#
# x2= 219.1304347826087
# y2= 258.2608695652174
#
# x2= 266.0869565217391
# y2= 246.52173913043478
# the distance between them is  48.40167473551167
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 258.2608695652174
#
# x2= 219.1304347826087
# y2= 258.2608695652174
#
# x2= 266.0869565217391
# y2= 246.52173913043478
# the distance between them is  48.40167473551167
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 219.1304347826087
# y1= 270.0
#
# x2= 219.1304347826087
# y2= 270.0
#
# x2= 281.7391304347826
# y2= 246.52173913043478
# the distance between them is  66.86611626770244
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 234.7826086956522
# y1= 270.0
#
# x2= 234.7826086956522
# y2= 270.0
#
# x2= 281.7391304347826
# y2= 246.52173913043478
# the distance between them is  52.49898729782115
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 234.7826086956522
# y1= 270.0
#
# x2= 234.7826086956522
# y2= 270.0
#
# x2= 281.7391304347826
# y2= 258.2608695652174
# the distance between them is  48.401674735511676
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 234.7826086956522
# y1= 270.0
#
# x2= 234.7826086956522
# y2= 270.0
#
# x2= 281.7391304347826
# y2= 258.2608695652174
# the distance between them is  48.401674735511676
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-c66adb3f3980> in <module>
#      11     hasFrame,frame = lean.read()
#      12     if not hasFrame:
# ---> 13         cv.WaitKey()
#      14         break
#      15     frameWidth = frame.shape[1]
#
# AttributeError: module 'cv2.cv2' has no attribute 'WaitKey'

# %%
lean = cv.VideoCapture(1)
lean1 = cv.VideoCapture('video2.mp4')

lean.set(cv.CAP_PROP_FPS,10)
lean.set(3,800)
lean.set(4,800)

if not lean.isOpened():
    lean = cv.VideoCapture(0)
if not lean.isOpened():
    raise IOError("can't access and open webcam")
    
while cv.waitKey(1) < 0:
    hasFrame,frame = lean.read()
    if not hasFrame:
        cv.WaitKey()
        break
    frameWidth = frame.shape[1]
    frameHeight = frame.shape[0]
    inp = cv.dnn.blobFromImage(frame, 1.0, (inWidth, inHeight),(127.5, 127.5, 127.5), swapRB=True, crop=False)
    net.setInput(inp)
    out = net.forward()
    out = out[:, :19, :, :]
    
    assert(len(BODY_PARTS) == out.shape[1])

    points = []
    for i in range(len(BODY_PARTS)):
        # Slice heatmap of corresponding body's part.
        heatMap = out[0, i, :, :]

        # Originally, we try to find all the local maximums. To simplify a sample
        # we just find a global one. However only a single pose at the same time
        # could be detected this way.
        _, conf, _, point = cv.minMaxLoc(heatMap)
        x = (frameWidth * point[0]) / out.shape[3]
        y = (frameHeight * point[1]) / out.shape[2]

        # Add a point if it's confidence is higher than threshold.
        points.append((int(x), int(y)) if conf > thr else None)
                
    for i in range(len(BODY_PART1)):
        heatMap = out[0, i, :, :]
        _, conf, _, point = cv.minMaxLoc(heatMap)
        x1 = (frameWidth * point[0]) / out.shape[3]
        y1 = (frameHeight * point[1]) / out.shape[2]
        print("       ")
        print("x1=",x1)
        print("y1=",y1)
        
    for i in range(len(element)):
        heatMap = out[0, i, :, :]
        _, conf, _, point = cv.minMaxLoc(heatMap)
        x2 = (frameWidth * point[0]) / out.shape[3]
        y2 = (frameHeight * point[1]) / out.shape[2]
        print("       ")
        print("x2=",x2)
        print("y2=",y2)
    distance = ((((x2-x1)**2)+((y2-y1)**2))**0.5)
    print("the distance between them is ", distance)
    
    for i in range(len('video2.mp4')):
        if distance <100:
            text = "bend pose detected: {}".format(distance)
            cv.putText(frame, text, (10, frame.shape[0] - 25),cv.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0),2)
            print("detected")
        else:
            text1 = "bend pose not detected: {}".format(distance)
            cv.putText(frame, text1, (10, frame.shape[0] - 25),cv.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0),2)
            print("not detected")

    for pair in POSE_PAIRS:
        partFrom = pair[0]
        partTo = pair[1]
        assert(partFrom in BODY_PARTS)
        assert(partTo in BODY_PARTS)

        idFrom = BODY_PARTS[partFrom]
        idTo = BODY_PARTS[partTo]

        if points[idFrom] and points[idTo]:
            cv.line(frame, points[idFrom], points[idTo], (0, 255, 0), 3)
            cv.ellipse(frame, points[idFrom], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)
            cv.ellipse(frame, points[idTo], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)

    t, _ = net.getPerfProfile()
    freq = cv.getTickFrequency() / 1000
    cv.putText(frame, '%.2fms' % (t / freq), (10, 20), cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0))
    
    cv.imshow('LIVE WEBCAM ', frame)
# Out:
#
# x1= 584.3478260869565
# y1= 0.0
#
# x2= 584.3478260869565
# y2= 0.0
#
# x2= 612.1739130434783
# y2= 20.869565217391305
# the distance between them is  34.782608695652186
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 584.3478260869565
# y1= 0.0
#
# x2= 584.3478260869565
# y2= 0.0
#
# x2= 389.5652173913044
# y2= 104.34782608695652
# the distance between them is  220.97224590286731
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 361.7391304347826
# y2= 83.47826086956522
# the distance between them is  247.54369876393855
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 264.3478260869565
# y1= 260.8695652173913
#
# x2= 264.3478260869565
# y2= 260.8695652173913
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  395.2994127353147
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 445.2173913043478
# y2= 156.52173913043478
# the distance between them is  211.57434887993807
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 473.04347826086956
# y2= 135.65217391304347
# the distance between them is  177.08413302758754
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 459.1304347826087
# the distance between them is  448.91130644995025
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 0.0
#
# x2= 598.2608695652174
# y2= 0.0
#
# x2= 612.1739130434783
# y2= 10.434782608695652
# the distance between them is  17.391304347826093
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 612.1739130434783
# y1= 20.869565217391305
#
# x2= 612.1739130434783
# y2= 20.869565217391305
#
# x2= 612.1739130434783
# y2= 20.869565217391305
# the distance between them is  0.0
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 598.2608695652174
# y1= 0.0
#
# x2= 598.2608695652174
# y2= 0.0
#
# x2= 612.1739130434783
# y2= 10.434782608695652
# the distance between them is  17.391304347826093
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 0.0
# the distance between them is  17.391304347826093
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 347.82608695652175
# y2= 0.0
# the distance between them is  250.65207964099434
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 626.0869565217391
# y2= 448.69565217391306
# the distance between them is  439.143348927628
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 389.5652173913044
# y2= 302.60869565217394
# the distance between them is  359.05357636351835
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 0.0
#
# x2= 598.2608695652174
# y2= 0.0
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.3478260869565
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 0.0
#
# x2= 598.2608695652174
# y2= 0.0
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.3478260869565
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 229.56521739130434
# the distance between them is  219.571674463814
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 584.3478260869565
# y1= 0.0
#
# x2= 584.3478260869565
# y2= 0.0
#
# x2= 612.1739130434783
# y2= 10.434782608695652
# the distance between them is  29.71827389675664
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 598.2608695652174
# y1= 0.0
#
# x2= 598.2608695652174
# y2= 0.0
#
# x2= 473.04347826086956
# y2= 125.21739130434783
# the distance between them is  177.08413302758754
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 0.0
#
# x2= 598.2608695652174
# y2= 0.0
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.3478260869565
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 0.0
#
# x2= 598.2608695652174
# y2= 0.0
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.3478260869565
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 403.4782608695652
# y2= 229.56521739130434
# the distance between them is  293.1866506140733
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 389.5652173913044
# y1= 166.95652173913044
#
# x2= 389.5652173913044
# y2= 166.95652173913044
#
# x2= 306.0869565217391
# y2= 333.9130434782609
# the distance between them is  186.66306594780855
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 389.5652173913044
# y1= 166.95652173913044
#
# x2= 389.5652173913044
# y2= 166.95652173913044
#
# x2= 320.0
# y2= 333.9130434782609
# the distance between them is  180.8695652173913
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 389.5652173913044
# y1= 156.52173913043478
#
# x2= 389.5652173913044
# y2= 156.52173913043478
#
# x2= 361.7391304347826
# y2= 114.78260869565217
# the distance between them is  50.16419165862942
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 389.5652173913044
# y1= 146.08695652173913
#
# x2= 389.5652173913044
# y2= 146.08695652173913
#
# x2= 361.7391304347826
# y2= 114.78260869565217
# the distance between them is  41.8838072305819
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 389.5652173913044
# y1= 146.08695652173913
#
# x2= 389.5652173913044
# y2= 146.08695652173913
#
# x2= 306.0869565217391
# y2= 333.9130434782609
# the distance between them is  205.54138021139698
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 375.6521739130435
# y1= 135.65217391304347
#
# x2= 375.6521739130435
# y2= 135.65217391304347
#
# x2= 347.82608695652175
# y2= 302.60869565217394
# the distance between them is  169.2594791039505
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 347.82608695652175
# y2= 281.7391304347826
# the distance between them is  369.22029940078187
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 320.0
# y2= 93.91304347826087
# the distance between them is  290.51287676968485
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 389.5652173913044
# y1= 52.17391304347826
#
# x2= 389.5652173913044
# y2= 52.17391304347826
#
# x2= 431.30434782608694
# y2= 302.60869565217394
# the distance between them is  253.8892186559257
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 292.17391304347825
# y1= 93.91304347826087
#
# x2= 292.17391304347825
# y2= 93.91304347826087
#
# x2= 292.17391304347825
# y2= 271.30434782608694
# the distance between them is  177.39130434782606
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 264.3478260869565
# y1= 125.21739130434783
#
# x2= 264.3478260869565
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 302.60869565217394
# the distance between them is  179.56047998803908
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 278.2608695652174
# y1= 125.21739130434783
#
# x2= 278.2608695652174
# y2= 125.21739130434783
#
# x2= 320.0
# y2= 313.04347826086956
# the distance between them is  192.40788432611245
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 278.2608695652174
# y1= 125.21739130434783
#
# x2= 278.2608695652174
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 281.7391304347826
# the distance between them is  157.13887997323852
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 292.17391304347825
# y1= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 271.30434782608694
# the distance between them is  146.08695652173913
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 292.17391304347825
# y1= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 281.7391304347826
# the distance between them is  156.5217391304348
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 292.17391304347825
# y1= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 125.21739130434783
#
# x2= 278.2608695652174
# y2= 156.52173913043478
# the distance between them is  34.25689670189949
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 292.17391304347825
# y1= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 125.21739130434783
#
# x2= 278.2608695652174
# y2= 156.52173913043478
# the distance between them is  34.25689670189949
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 292.17391304347825
# y1= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 156.52173913043478
# the distance between them is  31.304347826086953
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 292.17391304347825
# y1= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 271.30434782608694
# the distance between them is  146.08695652173913
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 292.17391304347825
# y1= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 125.21739130434783
#
# x2= 528.695652173913
# y2= 469.5652173913044
# the distance between them is  417.753466068324
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 292.17391304347825
# y1= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 125.21739130434783
#
# x2= 278.2608695652174
# y2= 156.52173913043478
# the distance between them is  34.25689670189949
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 292.17391304347825
# y1= 114.78260869565217
#
# x2= 292.17391304347825
# y2= 114.78260869565217
#
# x2= 306.0869565217391
# y2= 302.60869565217394
# the distance between them is  188.34067993990797
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 114.78260869565217
#
# x2= 306.0869565217391
# y2= 114.78260869565217
#
# x2= 292.17391304347825
# y2= 146.08695652173913
# the distance between them is  34.25689670189949
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 292.17391304347825
# the distance between them is  167.53522892232758
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 292.17391304347825
# y1= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 281.7391304347826
# the distance between them is  157.13887997323852
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 281.7391304347826
# the distance between them is  156.5217391304348
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 281.7391304347826
# the distance between them is  157.13887997323852
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 320.0
# y2= 281.7391304347826
# the distance between them is  157.13887997323852
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 281.7391304347826
# the distance between them is  157.13887997323852
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 135.65217391304347
#
# x2= 306.0869565217391
# y2= 135.65217391304347
#
# x2= 306.0869565217391
# y2= 292.17391304347825
# the distance between them is  156.52173913043478
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 135.65217391304347
#
# x2= 306.0869565217391
# y2= 135.65217391304347
#
# x2= 306.0869565217391
# y2= 292.17391304347825
# the distance between them is  156.52173913043478
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 135.65217391304347
#
# x2= 306.0869565217391
# y2= 135.65217391304347
#
# x2= 292.17391304347825
# y2= 292.17391304347825
# the distance between them is  157.13887997323852
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 156.52173913043478
# the distance between them is  34.25689670189949
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 292.17391304347825
# y1= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 125.21739130434783
#
# x2= 333.9130434782609
# y2= 302.60869565217394
# the distance between them is  182.2356437903268
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 278.2608695652174
# y1= 125.21739130434783
#
# x2= 278.2608695652174
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 281.7391304347826
# the distance between them is  157.13887997323852
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 250.43478260869566
# y1= 135.65217391304347
#
# x2= 250.43478260869566
# y2= 135.65217391304347
#
# x2= 292.17391304347825
# y2= 313.04347826086956
# the distance between them is  182.23564379032675
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 250.43478260869566
# y1= 135.65217391304347
#
# x2= 250.43478260869566
# y2= 135.65217391304347
#
# x2= 264.3478260869565
# y2= 313.04347826086956
# the distance between them is  177.93607739031182
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 250.43478260869566
# y1= 135.65217391304347
#
# x2= 250.43478260869566
# y2= 135.65217391304347
#
# x2= 278.2608695652174
# y2= 313.04347826086956
# the distance between them is  179.56047998803905
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 264.3478260869565
# y1= 125.21739130434783
#
# x2= 264.3478260869565
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 313.04347826086956
# the distance between them is  189.87609132460776
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 278.2608695652174
# y1= 125.21739130434783
#
# x2= 278.2608695652174
# y2= 125.21739130434783
#
# x2= 250.43478260869566
# y2= 93.91304347826087
# the distance between them is  41.88380723058189
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 292.17391304347825
# the distance between them is  167.53522892232758
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 135.65217391304347
#
# x2= 306.0869565217391
# y2= 135.65217391304347
#
# x2= 292.17391304347825
# y2= 292.17391304347825
# the distance between them is  157.13887997323852
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 320.0
# y1= 135.65217391304347
#
# x2= 320.0
# y2= 135.65217391304347
#
# x2= 292.17391304347825
# y2= 292.17391304347825
# the distance between them is  158.97592879341133
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 281.7391304347826
# the distance between them is  156.5217391304348
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 292.17391304347825
# the distance between them is  167.53522892232758
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 292.17391304347825
# y1= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 292.17391304347825
# the distance between them is  167.53522892232758
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 292.17391304347825
# the distance between them is  166.95652173913044
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 292.17391304347825
# the distance between them is  166.95652173913044
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 271.30434782608694
# the distance between them is  146.08695652173913
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 292.17391304347825
# the distance between them is  167.53522892232758
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 292.17391304347825
# the distance between them is  167.53522892232758
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 156.52173913043478
# the distance between them is  34.25689670189949
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 292.17391304347825
# the distance between them is  167.53522892232758
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 292.17391304347825
# y1= 135.65217391304347
#
# x2= 292.17391304347825
# y2= 135.65217391304347
#
# x2= 292.17391304347825
# y2= 166.95652173913044
# the distance between them is  31.304347826086968
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 292.17391304347825
# y1= 135.65217391304347
#
# x2= 292.17391304347825
# y2= 135.65217391304347
#
# x2= 278.2608695652174
# y2= 281.7391304347826
# the distance between them is  146.74798685028864
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 292.17391304347825
# y1= 146.08695652173913
#
# x2= 292.17391304347825
# y2= 146.08695652173913
#
# x2= 292.17391304347825
# y2= 281.7391304347826
# the distance between them is  135.6521739130435
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 0.0
#
# x2= 598.2608695652174
# y2= 0.0
#
# x2= 306.0869565217391
# y2= 302.60869565217394
# the distance between them is  420.6395346938374
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 333.9130434782609
# y2= 292.17391304347825
# the distance between them is  386.3375606578362
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 347.82608695652175
# y2= 302.60869565217394
# the distance between them is  384.8157686522249
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 0.0
#
# x2= 598.2608695652174
# y2= 0.0
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.3478260869565
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 198.2608695652174
#
# x2= 306.0869565217391
# y2= 198.2608695652174
#
# x2= 598.2608695652174
# y2= 459.1304347826087
# the distance between them is  391.6867696512722
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 347.82608695652175
# y2= 302.60869565217394
# the distance between them is  384.8157686522249
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 135.65217391304347
#
# x2= 306.0869565217391
# y2= 135.65217391304347
#
# x2= 292.17391304347825
# y2= 281.7391304347826
# the distance between them is  146.74798685028864
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 278.2608695652174
# y2= 281.7391304347826
# the distance between them is  158.97592879341136
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 292.17391304347825
# y1= 125.21739130434783
#
# x2= 292.17391304347825
# y2= 125.21739130434783
#
# x2= 278.2608695652174
# y2= 281.7391304347826
# the distance between them is  157.13887997323852
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 278.2608695652174
# y1= 146.08695652173913
#
# x2= 278.2608695652174
# y2= 146.08695652173913
#
# x2= 278.2608695652174
# y2= 271.30434782608694
# the distance between them is  125.21739130434781
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 292.17391304347825
# y1= 135.65217391304347
#
# x2= 292.17391304347825
# y2= 135.65217391304347
#
# x2= 292.17391304347825
# y2= 271.30434782608694
# the distance between them is  135.65217391304347
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 271.30434782608694
# the distance between them is  146.08695652173913
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 0.0
#
# x2= 598.2608695652174
# y2= 0.0
#
# x2= 417.39130434782606
# y2= 281.7391304347826
# the distance between them is  334.79954784926997
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 306.0869565217391
# y1= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 125.21739130434783
#
# x2= 306.0869565217391
# y2= 260.8695652173913
# the distance between them is  135.6521739130435
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 306.0869565217391
# y2= 302.60869565217394
# the distance between them is  413.19631039770434
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 333.9130434782609
# y1= 156.52173913043478
#
# x2= 333.9130434782609
# y2= 156.52173913043478
#
# x2= 320.0
# y2= 344.3478260869565
# the distance between them is  188.34067993990791
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 347.82608695652175
# y1= 166.95652173913044
#
# x2= 347.82608695652175
# y2= 166.95652173913044
#
# x2= 333.9130434782609
# y2= 344.3478260869565
# the distance between them is  177.9360773903118
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 347.82608695652175
# y1= 156.52173913043478
#
# x2= 347.82608695652175
# y2= 156.52173913043478
#
# x2= 333.9130434782609
# y2= 344.3478260869565
# the distance between them is  188.34067993990791
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 347.82608695652175
# y1= 146.08695652173913
#
# x2= 347.82608695652175
# y2= 146.08695652173913
#
# x2= 347.82608695652175
# y2= 333.9130434782609
# the distance between them is  187.82608695652175
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 347.82608695652175
# y1= 135.65217391304347
#
# x2= 347.82608695652175
# y2= 135.65217391304347
#
# x2= 375.6521739130435
# y2= 333.9130434782609
# the distance between them is  200.2040546943744
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 347.82608695652175
# y1= 135.65217391304347
#
# x2= 347.82608695652175
# y2= 135.65217391304347
#
# x2= 333.9130434782609
# y2= 166.95652173913044
# the distance between them is  34.25689670189951
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 347.82608695652175
# y1= 146.08695652173913
#
# x2= 347.82608695652175
# y2= 146.08695652173913
#
# x2= 361.7391304347826
# y2= 302.60869565217394
# the distance between them is  157.13887997323852
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 361.7391304347826
# y1= 146.08695652173913
#
# x2= 361.7391304347826
# y2= 146.08695652173913
#
# x2= 347.82608695652175
# y2= 302.60869565217394
# the distance between them is  157.13887997323852
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 347.82608695652175
# y1= 146.08695652173913
#
# x2= 347.82608695652175
# y2= 146.08695652173913
#
# x2= 333.9130434782609
# y2= 177.3913043478261
# the distance between them is  34.25689670189951
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 361.7391304347826
# y1= 135.65217391304347
#
# x2= 361.7391304347826
# y2= 135.65217391304347
#
# x2= 347.82608695652175
# y2= 166.95652173913044
# the distance between them is  34.25689670189951
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 361.7391304347826
# y1= 135.65217391304347
#
# x2= 361.7391304347826
# y2= 135.65217391304347
#
# x2= 347.82608695652175
# y2= 166.95652173913044
# the distance between them is  34.25689670189951
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 361.7391304347826
# y1= 135.65217391304347
#
# x2= 361.7391304347826
# y2= 135.65217391304347
#
# x2= 347.82608695652175
# y2= 166.95652173913044
# the distance between them is  34.25689670189951
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 361.7391304347826
# y2= 281.7391304347826
# the distance between them is  359.92857934682513
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 361.7391304347826
# y1= 177.3913043478261
#
# x2= 361.7391304347826
# y2= 177.3913043478261
#
# x2= 361.7391304347826
# y2= 292.17391304347825
# the distance between them is  114.78260869565216
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 361.7391304347826
# y1= 166.95652173913044
#
# x2= 361.7391304347826
# y2= 166.95652173913044
#
# x2= 347.82608695652175
# y2= 281.7391304347826
# the distance between them is  115.62274879022374
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 361.7391304347826
# y1= 146.08695652173913
#
# x2= 361.7391304347826
# y2= 146.08695652173913
#
# x2= 361.7391304347826
# y2= 271.30434782608694
# the distance between them is  125.21739130434781
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 375.6521739130435
# y1= 146.08695652173913
#
# x2= 375.6521739130435
# y2= 146.08695652173913
#
# x2= 361.7391304347826
# y2= 281.7391304347826
# the distance between them is  136.3637967576533
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 389.5652173913044
# y1= 166.95652173913044
#
# x2= 389.5652173913044
# y2= 166.95652173913044
#
# x2= 375.6521739130435
# y2= 302.60869565217394
# the distance between them is  136.3637967576533
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 361.7391304347826
# y2= 302.60869565217394
# the distance between them is  375.90973456991435
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 612.1739130434783
# y2= 448.69565217391306
# the distance between them is  438.48165591149706
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# ...
# detected
#
# x1= 389.5652173913044
# y1= 114.78260869565217
#
# x2= 389.5652173913044
# y2= 114.78260869565217
#
# x2= 389.5652173913044
# y2= 313.04347826086956
# the distance between them is  198.26086956521738
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 389.5652173913044
# y1= 114.78260869565217
#
# x2= 389.5652173913044
# y2= 114.78260869565217
#
# x2= 389.5652173913044
# y2= 177.3913043478261
# the distance between them is  62.60869565217392
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 389.5652173913044
# y1= 125.21739130434783
#
# x2= 389.5652173913044
# y2= 125.21739130434783
#
# x2= 389.5652173913044
# y2= 156.52173913043478
# the distance between them is  31.304347826086953
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 389.5652173913044
# y1= 146.08695652173913
#
# x2= 389.5652173913044
# y2= 146.08695652173913
#
# x2= 403.4782608695652
# y2= 281.7391304347826
# the distance between them is  136.3637967576533
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 403.4782608695652
# y1= 125.21739130434783
#
# x2= 403.4782608695652
# y2= 125.21739130434783
#
# x2= 389.5652173913044
# y2= 302.60869565217394
# the distance between them is  177.93607739031185
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 361.7391304347826
# y1= 104.34782608695652
#
# x2= 361.7391304347826
# y2= 104.34782608695652
#
# x2= 375.6521739130435
# y2= 302.60869565217394
# the distance between them is  198.74844698659695
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 389.5652173913044
# y1= 104.34782608695652
#
# x2= 389.5652173913044
# y2= 104.34782608695652
#
# x2= 389.5652173913044
# y2= 292.17391304347825
# the distance between them is  187.82608695652175
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 459.1304347826087
# y1= 114.78260869565217
#
# x2= 459.1304347826087
# y2= 114.78260869565217
#
# x2= 445.2173913043478
# y2= 135.65217391304347
# the distance between them is  25.082095829314706
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 459.1304347826087
# y1= 114.78260869565217
#
# x2= 459.1304347826087
# y2= 114.78260869565217
#
# x2= 417.39130434782606
# y2= 281.7391304347826
# the distance between them is  172.0948435040415
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 473.04347826086956
# y1= 125.21739130434783
#
# x2= 473.04347826086956
# y2= 125.21739130434783
#
# x2= 459.1304347826087
# y2= 146.08695652173913
# the distance between them is  25.082095829314706
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 486.95652173913044
# y1= 114.78260869565217
#
# x2= 486.95652173913044
# y2= 114.78260869565217
#
# x2= 417.39130434782606
# y2= 292.17391304347825
# the distance between them is  190.54394330159772
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 584.3478260869565
# y1= 0.0
#
# x2= 584.3478260869565
# y2= 0.0
#
# x2= 612.1739130434783
# y2= 10.434782608695652
# the distance between them is  29.71827389675664
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 556.5217391304348
# y1= 156.52173913043478
#
# x2= 556.5217391304348
# y2= 156.52173913043478
#
# x2= 612.1739130434783
# y2= 20.869565217391305
# the distance between them is  146.62427066683819
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 0.0
#
# x2= 598.2608695652174
# y2= 0.0
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.3478260869565
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 612.1739130434783
# y1= 20.869565217391305
#
# x2= 612.1739130434783
# y2= 20.869565217391305
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  598.6247629402687
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 375.6521739130435
# y2= 271.30434782608694
# the distance between them is  342.9395886109869
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 347.82608695652175
# y1= 114.78260869565217
#
# x2= 347.82608695652175
# y2= 114.78260869565217
#
# x2= 375.6521739130435
# y2= 281.7391304347826
# the distance between them is  169.25947910395047
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 375.6521739130435
# y1= 114.78260869565217
#
# x2= 375.6521739130435
# y2= 114.78260869565217
#
# x2= 361.7391304347826
# y2= 156.52173913043478
# the distance between them is  43.99690657625572
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 389.5652173913044
# y1= 114.78260869565217
#
# x2= 389.5652173913044
# y2= 114.78260869565217
#
# x2= 361.7391304347826
# y2= 292.17391304347825
# the distance between them is  179.56047998803902
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 403.4782608695652
# y1= 125.21739130434783
#
# x2= 403.4782608695652
# y2= 125.21739130434783
#
# x2= 375.6521739130435
# y2= 166.95652173913044
# the distance between them is  50.16419165862939
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 403.4782608695652
# y1= 114.78260869565217
#
# x2= 403.4782608695652
# y2= 114.78260869565217
#
# x2= 375.6521739130435
# y2= 292.17391304347825
# the distance between them is  179.56047998803902
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 403.4782608695652
# y1= 114.78260869565217
#
# x2= 403.4782608695652
# y2= 114.78260869565217
#
# x2= 389.5652173913044
# y2= 302.60869565217394
# the distance between them is  188.34067993990797
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 403.4782608695652
# y1= 125.21739130434783
#
# x2= 403.4782608695652
# y2= 125.21739130434783
#
# x2= 375.6521739130435
# y2= 302.60869565217394
# the distance between them is  179.56047998803908
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 361.7391304347826
# y1= 146.08695652173913
#
# x2= 361.7391304347826
# y2= 146.08695652173913
#
# x2= 347.82608695652175
# y2= 31.304347826086957
# the distance between them is  115.62274879022374
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 361.7391304347826
# y1= 135.65217391304347
#
# x2= 361.7391304347826
# y2= 135.65217391304347
#
# x2= 347.82608695652175
# y2= 156.52173913043478
# the distance between them is  25.082095829314717
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 347.82608695652175
# y1= 125.21739130434783
#
# x2= 347.82608695652175
# y2= 125.21739130434783
#
# x2= 347.82608695652175
# y2= 156.52173913043478
# the distance between them is  31.304347826086953
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 431.30434782608694
# y2= 302.60869565217394
# the distance between them is  336.51162775507
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 361.7391304347826
# y1= 125.21739130434783
#
# x2= 361.7391304347826
# y2= 125.21739130434783
#
# x2= 375.6521739130435
# y2= 292.17391304347825
# the distance between them is  167.53522892232758
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 389.5652173913044
# y2= 281.7391304347826
# the distance between them is  342.28631930831426
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 417.39130434782606
# y2= 271.30434782608694
# the distance between them is  317.4377571723927
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 417.39130434782606
# y1= 114.78260869565217
#
# x2= 417.39130434782606
# y2= 114.78260869565217
#
# x2= 403.4782608695652
# y2= 271.30434782608694
# the distance between them is  157.13887997323846
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 347.82608695652175
# y1= 125.21739130434783
#
# x2= 347.82608695652175
# y2= 125.21739130434783
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  356.6192867610796
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 333.9130434782609
# y1= 83.47826086956522
#
# x2= 333.9130434782609
# y2= 83.47826086956522
#
# x2= 361.7391304347826
# y2= 292.17391304347825
# the distance between them is  210.5425523536912
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 389.5652173913044
# y2= 313.04347826086956
# the distance between them is  367.5947468620912
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 375.6521739130435
# y1= 125.21739130434783
#
# x2= 375.6521739130435
# y2= 125.21739130434783
#
# x2= 389.5652173913044
# y2= 313.04347826086956
# the distance between them is  188.34067993990797
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 389.5652173913044
# y1= 125.21739130434783
#
# x2= 389.5652173913044
# y2= 125.21739130434783
#
# x2= 417.39130434782606
# y2= 323.4782608695652
# the distance between them is  200.20405469437438
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 389.5652173913044
# y1= 125.21739130434783
#
# x2= 389.5652173913044
# y2= 125.21739130434783
#
# x2= 403.4782608695652
# y2= 313.04347826086956
# the distance between them is  188.34067993990797
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 375.6521739130435
# y1= 125.21739130434783
#
# x2= 375.6521739130435
# y2= 125.21739130434783
#
# x2= 431.30434782608694
# y2= 323.4782608695652
# the distance between them is  205.92361899987037
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 389.5652173913044
# y1= 125.21739130434783
#
# x2= 389.5652173913044
# y2= 125.21739130434783
#
# x2= 403.4782608695652
# y2= 323.4782608695652
# the distance between them is  198.7484469865969
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 375.6521739130435
# y1= 125.21739130434783
#
# x2= 375.6521739130435
# y2= 125.21739130434783
#
# x2= 417.39130434782606
# y2= 323.4782608695652
# the distance between them is  202.60682962380102
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 375.6521739130435
# y1= 114.78260869565217
#
# x2= 375.6521739130435
# y2= 114.78260869565217
#
# x2= 389.5652173913044
# y2= 302.60869565217394
# the distance between them is  188.34067993990797
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 375.6521739130435
# y1= 114.78260869565217
#
# x2= 375.6521739130435
# y2= 114.78260869565217
#
# x2= 389.5652173913044
# y2= 302.60869565217394
# the distance between them is  188.34067993990797
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 292.17391304347825
# y2= 302.60869565217394
# the distance between them is  423.1486977598762
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 361.7391304347826
# y2= 260.8695652173913
# the distance between them is  344.47077295693765
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 598.2608695652174
# y1= 10.434782608695652
#
# x2= 598.2608695652174
# y2= 10.434782608695652
#
# x2= 13.91304347826087
# y2= 0.0
# the distance between them is  584.4409863627317
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
# not detected
#
# x1= 375.6521739130435
# y1= 219.1304347826087
#
# x2= 375.6521739130435
# y2= 219.1304347826087
#
# x2= 361.7391304347826
# y2= 260.8695652173913
# the distance between them is  43.996906576255725
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
# detected
